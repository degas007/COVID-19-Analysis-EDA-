# %%
import pandas as pd

# %%
df = pd.read_csv('Complete covid_19.csv')
df
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
dfh =df.head(7000)
dfh
# Out:
#             Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0     2020-01-22    Afghanistan          0       0          0       0
# 1     2020-01-22        Albania          0       0          0       0
# 2     2020-01-22        Algeria          0       0          0       0
# 3     2020-01-22        Andorra          0       0          0       0
# 4     2020-01-22         Angola          0       0          0       0
# ...          ...            ...        ...     ...        ...     ...
# 6995  2020-02-28       Honduras          0       0          0       0
# 6996  2020-02-28        Hungary          0       0          0       0
# 6997  2020-02-28        Iceland          1       0          0       1
# 6998  2020-02-28          India          3       0          3       0
# 6999  2020-02-28      Indonesia          0       0          0       0
#
#       New cases  New deaths  New recovered             WHO Region  Year
# ...

# %%
plt.xticks(rotation=90)
sns.lineplot(x ='Date', y='Confirmed', data=dfh)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed'>

# %%
dft = df.tail(7000)
dft
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 28156  2020-06-20            Maldives       2187       8       1788     391
# 28157  2020-06-20                Mali       1933     109       1255     569
# 28158  2020-06-20               Malta        664       9        616      39
# 28159  2020-06-20          Mauritania       2813     108        696    2009
# 28160  2020-06-20           Mauritius        337      10        326       1
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
plt.xticks(rotation=90)
sns.lineplot(x ='Date', y='Confirmed', data=dft)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed'>

# %%
dfd = df.head(10000)
dfd
# Out:
#             Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0     2020-01-22    Afghanistan          0       0          0       0
# 1     2020-01-22        Albania          0       0          0       0
# 2     2020-01-22        Algeria          0       0          0       0
# 3     2020-01-22        Andorra          0       0          0       0
# 4     2020-01-22         Angola          0       0          0       0
# ...          ...            ...        ...     ...        ...     ...
# 9995  2020-03-15         Israel        213       0          4     209
# 9996  2020-03-15          Italy      24747    1809       2335   20603
# 9997  2020-03-15        Jamaica         10       0          0      10
# 9998  2020-03-15          Japan        826      24        118     684
# 9999  2020-03-15         Jordan          8       0          1       7
#
#       New cases  New deaths  New recovered             WHO Region  Year
# ...

# %%
plt.xticks(rotation=90)
sns.lineplot(x ='Date', y='Deaths', data=dfd)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Deaths'>

# %%
dfdt = df.tail(10000)
dfdt
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 25156  2020-06-04             Liberia        321      28        175     118
# 25157  2020-06-04               Libya        209       5         52     152
# 25158  2020-06-04       Liechtenstein         82       1         81       0
# 25159  2020-06-04           Lithuania       1687      71       1273     343
# 25160  2020-06-04          Luxembourg       4027     110       3874      43
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
plt.xticks(rotation=90)
sns.lineplot(x ='Date', y='Deaths', data=dfdt)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Deaths'>

# %%
plt.xticks(rotation=90)
sns.lineplot(x ='Date', y='Recovered', data=dfdt)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Recovered'>

# %%
plt.xticks(rotation=90)
sns.lineplot(x ='Date', y='Recovered', data=dfd)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Recovered'>

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year
df
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="WHO Region",y='Confirmed', data=df )
plt.xticks(rotation=45)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="WHO Region",y='Deaths', data=df )
plt.xticks(rotation=45)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="WHO Region",y='Recovered', data=df )
plt.xticks(rotation=45)
sns.set(rc={'figure.figsize':(20,8)})

# %%
df1 = df[df['WHO Region'].str.startswith('Af')]
df1
# Out:
#              Date  Country/Region  Confirmed  Deaths  Recovered  Active  \
# 2      2020-01-22         Algeria          0       0          0       0
# 4      2020-01-22          Angola          0       0          0       0
# 18     2020-01-22           Benin          0       0          0       0
# 22     2020-01-22        Botswana          0       0          0       0
# 26     2020-01-22    Burkina Faso          0       0          0       0
# ...           ...             ...        ...     ...        ...     ...
# 35138  2020-07-27            Togo        874      18        607     249
# 35143  2020-07-27          Uganda       1128       2        986     140
# 35152  2020-07-27  Western Sahara         10       1          8       1
# 35154  2020-07-27          Zambia       4552     140       2815    1597
# 35155  2020-07-27        Zimbabwe       2704      36        542    2126
#
#        New cases  New deaths  New recovered WHO Region
# ...

# %%
sns.barplot(x="Country/Region",y='Confirmed', data=df1 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Deaths', data=df1 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Recovered', data=df1 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
df2= df[df['WHO Region'].str.startswith('Eu')]
df2
# Out:
#              Date  Country/Region  Confirmed  Deaths  Recovered  Active  \
# 1      2020-01-22         Albania          0       0          0       0
# 3      2020-01-22         Andorra          0       0          0       0
# 7      2020-01-22         Armenia          0       0          0       0
# 9      2020-01-22         Austria          0       0          0       0
# 10     2020-01-22      Azerbaijan          0       0          0       0
# ...           ...             ...        ...     ...        ...     ...
# 35134  2020-07-27      Tajikistan       7235      60       6028    1147
# 35141  2020-07-27          Turkey     227019    5630     210469   10920
# 35144  2020-07-27         Ukraine      67096    1636      37202   28258
# 35146  2020-07-27  United Kingdom     301708   45844       1437  254427
# 35148  2020-07-27      Uzbekistan      21209     121      11674    9414
#
#        New cases  New deaths  New recovered WHO Region
# ...

# %%
sns.barplot(x="Country/Region",y='Confirmed', data=df2 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Deaths', data=df2 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Recovered', data=df2)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
df3= df[df['WHO Region'].str.startswith('Am')]
df3
# Out:
#              Date       Country/Region  Confirmed  Deaths  Recovered   Active  \
# 5      2020-01-22  Antigua and Barbuda          0       0          0        0
# 6      2020-01-22            Argentina          0       0          0        0
# 11     2020-01-22              Bahamas          0       0          0        0
# 14     2020-01-22             Barbados          0       0          0        0
# 17     2020-01-22               Belize          0       0          0        0
# ...           ...                  ...        ...     ...        ...      ...
# 35129  2020-07-27             Suriname       1483      24        925      534
# 35139  2020-07-27  Trinidad and Tobago        148       8        128       12
# 35142  2020-07-27                   US    4290259  148011    1325804  2816444
# 35147  2020-07-27              Uruguay       1202      35        951      216
# 35149  2020-07-27            Venezuela      15988     146       9959     5883
#
# ...

# %%
sns.barplot(x="Country/Region",y='Confirmed', data=df3 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Deaths', data=df3)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Recovered', data=df3)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
df4= df[df['WHO Region'].str.startswith('We')]
df4
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 8      2020-01-22      Australia          0       0          0       0
# 24     2020-01-22         Brunei          0       0          0       0
# 30     2020-01-22       Cambodia          0       0          0       0
# 36     2020-01-22          China        548      17         28     503
# 59     2020-01-22           Fiji          0       0          0       0
# ...           ...            ...        ...     ...        ...     ...
# 35102  2020-07-27    Philippines      82040    1945      26446   53649
# 35119  2020-07-27      Singapore      50838      27      45692    5119
# 35124  2020-07-27    South Korea      14203     300      13007     896
# 35133  2020-07-27        Taiwan*        462       7        440      15
# 35150  2020-07-27        Vietnam        431       0        365      66
#
#        New cases  New deaths  New recovered       WHO Region
# ...

# %%
sns.barplot(x="Country/Region",y='Confirmed', data=df4)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
df5= df[df['WHO Region'].str.startswith('Ea')]
df5
# Out:
#              Date        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22           Afghanistan          0       0          0       0
# 12     2020-01-22               Bahrain          0       0          0       0
# 48     2020-01-22              Djibouti          0       0          0       0
# 52     2020-01-22                 Egypt          0       0          0       0
# 81     2020-01-22                  Iran          0       0          0       0
# ...           ...                   ...        ...     ...        ...     ...
# 35132  2020-07-27                 Syria        674      40          0     634
# 35140  2020-07-27               Tunisia       1455      50       1157     248
# 35145  2020-07-27  United Arab Emirates      59177     345      52510    6322
# 35151  2020-07-27    West Bank and Gaza      10621      78       3752    6791
# 35153  2020-07-27                 Yemen       1691     483        833     375
#
# ...

# %%
sns.barplot(x="Country/Region",y='Confirmed', data=df5)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Deaths', data=df5)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Recovered', data=df5 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
df6= df[df['WHO Region'].str.startswith('So')]
df6
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 13     2020-01-22     Bangladesh          0       0          0       0
# 19     2020-01-22         Bhutan          0       0          0       0
# 27     2020-01-22          Burma          0       0          0       0
# 79     2020-01-22          India          0       0          0       0
# 80     2020-01-22      Indonesia          0       0          0       0
# ...           ...            ...        ...     ...        ...     ...
# 35075  2020-07-27       Maldives       3369      15       2547     807
# 35088  2020-07-27          Nepal      18752      48      13754    4950
# 35127  2020-07-27      Sri Lanka       2805      11       2121     673
# 35136  2020-07-27       Thailand       3297      58       3111     128
# 35137  2020-07-27    Timor-Leste         24       0          0      24
#
#        New cases  New deaths  New recovered       WHO Region
# ...

# %%
sns.barplot(x="Country/Region",y='Confirmed', data=df6)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Deaths', data=df6 )
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})

# %%
sns.barplot(x="Country/Region",y='Recovered', data=df6)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(20,8)})
